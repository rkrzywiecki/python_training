# %%
from sympy import *

# %%
x = symbols('x')
f = 2*x+1
plot(f)

# %%
x = symbols('x')
f = x**2 + 1 
plot(f)

# %%
from sympy import *
from sympy.plotting import plot3d
x, y = symbols('x y')
f = 2*x + 3*y
plot3d(f)

# %%
suma = sum(2*i for i in range(1,6))
print(suma)
# Out:
# 30
